# %%
2+2
# Out:
# 4

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df =pd.read_csv('/content/survey lung cancer.csv')

# %%
df.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS FF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
df.tail()
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS FF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    int64
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS FF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(15), object(1)
# memory usage: 38.8+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS FF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 16 columns]>

# %%
df.shape
# Out:
# (309, 16)

# %%
df['GENDER'].replace({'M:1', 'F:0'}, inplace = True)
df.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS FF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
x=df['SMOKING']
y=df['AGE']

# %%
print(x,y)
# Out:
# 0      1
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 304    1
# 305    2
# 306    2
# 307    2
# 308    1
# Name: SMOKING, Length: 309, dtype: int64 0      69
# 1      74
# 2      59
# 3      63
# 4      63
#        ..
# 304    56
# 305    70
# 306    58
# 307    67
# 308    62
# Name: AGE, Length: 309, dtype: int64

# %%
plt.plot(x,y)
plt.xlabel('SMOKING')
plt.ylabel('AGE')
# Out:
# Text(0, 0.5, 'AGE')

# %%
plt.scatter(x,y)
plt.xlabel('SMOKING')
plt.ylabel('AGE')
# Out:
# Text(0, 0.5, 'AGE')

# %%
plt.bar(x,y)
plt.xlabel('SMOKING')
plt.ylabel('AGE')
# Out:
# Text(0, 0.5, 'AGE')

# %%
x = df['SMOKING']

# %%
print(x)
# Out:
# 0      1
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 304    1
# 305    2
# 306    2
# 307    2
# 308    1
# Name: SMOKING, Length: 309, dtype: int64

# %%
plt.pie(x)
plt.xlabel('SMOKING')
# Out:
# Text(0.5, 0, 'SMOKING')

# %%
plt.hist(x)
plt.xlabel('SMOKING')
# Out:
# Text(0.5, 0, 'SMOKING')

# %%
x = df['AGE']
y = df['CHEST PAIN']

# %%
print(x,y)
# Out:
# 0      69
# 1      74
# 2      59
# 3      63
# 4      63
#        ..
# 304    56
# 305    70
# 306    58
# 307    67
# 308    62
# Name: AGE, Length: 309, dtype: int64 0      2
# 1      2
# 2      2
# 3      2
# 4      1
#       ..
# 304    1
# 305    2
# 306    2
# 307    2
# 308    1
# Name: CHEST PAIN, Length: 309, dtype: int64

# %%
sns.lineplot(x)
q=set('AGE')

# %%
sns.countplot(x)
q = set('AGE')

# %%
sns.scatterplot(x = df['AGE'], y = df['CHEST PAIN'])
# Out:
# <Axes: xlabel='AGE', ylabel='CHEST PAIN'>

# %%
sns.barplot(x=df['AGE'], y = df['CHEST PAIN'])
# Out:
# <Axes: xlabel='AGE', ylabel='CHEST PAIN'>

# %%
sns.pairplot(df, hue="LUNG_CANCER")

# %%
df.isnull()
# Out:
#      GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0     False  False    False           False    False          False
# 1     False  False    False           False    False          False
# 2     False  False    False           False    False          False
# 3     False  False    False           False    False          False
# 4     False  False    False           False    False          False
# ..      ...    ...      ...             ...      ...            ...
# 304   False  False    False           False    False          False
# 305   False  False    False           False    False          False
# 306   False  False    False           False    False          False
# 307   False  False    False           False    False          False
# 308   False  False    False           False    False          False
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0              False     False     False     False              False
# 1              False     False     False     False              False
# 2              False     False     False     False              False
# 3              False     False     False     False              False
# 4              False     False     False     False              False
# ..               ...       ...       ...       ...                ...
# 304            False     False     False     False              False
# 305            False     False     False     False              False
# 306            False     False     False     False              False
# 307            False     False     False     False              False
# 308            False     False     False     False              False
#
#      COUGHING  SHORTNESS FF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0       False                False                  False       False
# 1       False                False                  False       False
# 2       False                False                  False       False
# 3       False                False                  False       False
# 4       False                False                  False       False
# ..        ...                  ...                    ...         ...
# 304     False                False                  False       False
# 305     False                False                  False       False
# 306     False                False                  False       False
# 307     False                False                  False       False
# 308     False                False                  False       False
#
#      LUNG_CANCER
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ..           ...
# 304        False
# 305        False
# 306        False
# 307        False
# 308        False
#
# [309 rows x 16 columns]

# %%
sns.boxplot(x=df['AGE'])
# Out:
# <Axes: xlabel='AGE'>

# %%
x = df.drop('LUNG_CANCER', axis = 1)

# %%
y = df['LUNG_CANCER']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.5, random_state = 0)

# %%
print(y)
# Out:
# 0      YES
# 1      YES
# 2       NO
# 3       NO
# 4       NO
#       ...
# 304    YES
# 305    YES
# 306    YES
# 307    YES
# 308    YES
# Name: LUNG_CANCER, Length: 309, dtype: object

# %%
print(x)
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS FF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
# [309 rows x 15 columns]

# %%
x_train.shape
# Out:
# (154, 15)

# %%
y_train.shape
# Out:
# (154,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
a = StandardScaler()

# %%
x_train = a.fit_transform(x_train)

# %%
print(x_train)
# Out:
# [[-1.10990272 -0.34085447  0.93704257 ... -1.28653504  0.9617692
#    0.80988516]
#  [-1.10990272 -0.21467277  0.93704257 ...  0.77728159  0.9617692
#    0.80988516]
#  [ 0.90097986  0.03769064  0.93704257 ... -1.28653504  0.9617692
#    0.80988516]
#  ...
#  [-1.10990272 -1.4764898   0.93704257 ...  0.77728159  0.9617692
#   -1.23474295]
#  [-1.10990272  0.16387234  0.93704257 ... -1.28653504  0.9617692
#    0.80988516]
#  [ 0.90097986 -0.84558128 -1.06718737 ... -1.28653504 -1.03975049
#   -1.23474295]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = clf.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_predict, y_test)
# Out:
# 0.8451612903225807

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_predict,y_test)
# Out:
# array([[  0,   0],
#        [ 24, 131]])

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
graphviz.Source(export_graphviz(clf,feature_names = x.columns, filled = True))
